# %%
from lxml import html
from lxml import etree
import requests
import pandas as pd

"""
page = requests.get('http://www.sports-reference.com/cbb/seasons/2016-school-stats.html')
tree = html.fromstring(page.content)
table = tree.xpath('//table[@class="sortable"]//tr[@sstyle="text-align:center;"]')
"""
# Out:
# '\npage = requests.get(\'http://www.sports-reference.com/cbb/seasons/2016-school-stats.html\')\ntree = html.fromstring(page.content)\ntable = tree.xpath(\'//table[@class="sortable"]//tr[@sstyle="text-align:center;"]\')\n'

# %%
def getURL(year):
    base = 'http://www.sports-reference.com/cbb/seasons/'
    base += str(year) + "-school-stats.html"
    return base

# %%
for year in range(2003, 2004):
    url = getURL(year)
    page = requests.get(url)
    tree = html.fromstring(page.content)
    players = tree.xpath('//table[@class="sortable"]//tr')
    print page.text
# Out:
# <!DOCTYPE html>
# <html data-version="klecko-" data-root="/home/cbb/build" itemscope itemtype="http://schema.org/WebSite" lang="en" class="no-js" >
# <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />
#     <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201701202" />
#     <link href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect" crossorigin>
# <link href="https://d9kjk42l7bfqz.cloudfront.net/req/201610011" rel="preconnect" crossorigin>
# <link href="https://www.google-analytics.com/" rel="preconnect" crossorigin>
# <link href="https://www.googletagservices.com" rel="preconnect" crossorigin>
#
#
#
# <script class="allowed">var sr_is_production = true;
# ...
